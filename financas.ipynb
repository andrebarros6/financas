# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cont = pd.read_csv(r"C:\Users\abarr\Documents\projects\financas\financas\2025sire.csv", sep = ";")

# %%
cont.head()
# Out:
#          Referência Tipo Documento        ATCUD Situação  \
# 0  FR ATSIRE01FR/70  Fatura-Recibo  JJMD3KXT-70  Emitido
# 1  FR ATSIRE01FR/69  Fatura-Recibo  JJMD3KXT-69  Emitido
# 2  FR ATSIRE01FR/68  Fatura-Recibo  JJMD3KXT-68  Emitido
# 3  FR ATSIRE01FR/67  Fatura-Recibo  JJMD3KXT-67  Emitido
# 4  FR ATSIRE01FR/66  Fatura-Recibo  JJMD3KXT-66  Emitido
#
#                     Data da Transação Motivo Emissão Data de Emissão  \
# 0  Pagamento dos bens ou dos serviços     2025-12-27      2025-12-27
# 1  Pagamento dos bens ou dos serviços     2025-12-05      2025-12-05
# 2  Pagamento dos bens ou dos serviços     2025-12-05      2025-12-05
# 3  Pagamento dos bens ou dos serviços     2025-12-05      2025-12-05
# 4  Pagamento dos bens ou dos serviços     2025-11-17      2025-11-22
#
#   País do Adquirente  NIF Adquirente  \
# 0           PORTUGAL       510927874
# 1           PORTUGAL       516805401
# 2           PORTUGAL       500600651
# 3           PORTUGAL       517283972
# 4           PORTUGAL       510927874
#
#                              Nome do Adquirente Valor Tributável (em euros)  \
# 0  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA                      384,97
# 1                          OLINDA & BEATRIZ LDA                      258,95
# 2  EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA                      891,45
# 3                             EVORAL CENTER LDA                         220
# 4  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA                      101,67
#
#    Valor do IVA (em euros)  Imposto do Selo como Retenção na Fonte  \
# 0                        0                                     NaN
# 1                        0                                     NaN
# 2                        0                                     NaN
# 3                        0                                     NaN
# 4                        0                                     NaN
#
#    Valor do Imposto do Selo (em euros) Valor do IRS (em euros)  \
# 0                                    0                   88,54
# 1                                    0                  59,558
# 2                                    0                 222,862
# 3                                    0                    50,6
# 4                                    0                  23,384
#
#    Total de Impostos (em euros) Total com Impostos (em euros)  \
# 0                           NaN                        384,97
# 1                           NaN                        258,95
# 2                           NaN                        891,45
# 3                           NaN                           220
# 4                           NaN                        101,67
#
#   Total de Retenções na Fonte (em euros)  Contribuição Cultura (em euros)  \
# 0                                  88,54                                0
# 1                                 59,558                                0
# 2                                222,862                                0
# 3                                   50,6                                0
# 4                                 23,384                                0
#
#   Total do Documento (em euros)
# 0                        296,43
# 1                       199,392
# 2                       668,588
# 3                         169,4
# 4                        78,286

# %%
cont.nunique()
# Out:
# Referência                                57
# Tipo Documento                             2
# ATCUD                                     57
# Situação                                   2
# Data da Transação                          1
# Motivo Emissão                            35
# Data de Emissão                           24
# País do Adquirente                         1
# NIF Adquirente                             6
# Nome do Adquirente                         6
# Valor Tributável (em euros)               55
# Valor do IVA (em euros)                    1
# Imposto do Selo como Retenção na Fonte     0
# Valor do Imposto do Selo (em euros)        1
# Valor do IRS (em euros)                   54
# Total de Impostos (em euros)               0
# Total com Impostos (em euros)             55
# Total de Retenções na Fonte (em euros)    54
# Contribuição Cultura (em euros)            1
# Total do Documento (em euros)             54
# dtype: int64

# %%
cont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Referência                              57 non-null     object
#  1   Tipo Documento                          57 non-null     object
#  2   ATCUD                                   57 non-null     object
#  3   Situação                                57 non-null     object
#  4   Data da Transação                       57 non-null     object
#  5   Motivo Emissão                          57 non-null     object
#  6   Data de Emissão                         57 non-null     object
#  7   País do Adquirente                      57 non-null     object
#  8   NIF Adquirente                          57 non-null     int64
#  9   Nome do Adquirente                      57 non-null     object
#  10  Valor Tributável (em euros)             57 non-null     object
#  11  Valor do IVA (em euros)                 57 non-null     int64
#  12  Imposto do Selo como Retenção na Fonte  0 non-null      float64
#  13  Valor do Imposto do Selo (em euros)     57 non-null     int64
#  14  Valor do IRS (em euros)                 57 non-null     object
#  15  Total de Impostos (em euros)            0 non-null      float64
#  16  Total com Impostos (em euros)           57 non-null     object
#  17  Total de Retenções na Fonte (em euros)  57 non-null     object
#  18  Contribuição Cultura (em euros)         57 non-null     int64
#  19  Total do Documento (em euros)           57 non-null     object
# dtypes: float64(2), int64(4), object(14)
# memory usage: 9.0+ KB

# %%
cont_selected = cont[["Data de Emissão", "Nome do Adquirente", "Total do Documento (em euros)"]]
cont_selected.head()
# Out:
#   Data de Emissão                            Nome do Adquirente  \
# 0      2025-12-27  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA
# 1      2025-12-05                          OLINDA & BEATRIZ LDA
# 2      2025-12-05  EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA
# 3      2025-12-05                             EVORAL CENTER LDA
# 4      2025-11-22  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA
#
#   Total do Documento (em euros)
# 0                        296,43
# 1                       199,392
# 2                       668,588
# 3                         169,4
# 4                        78,286

# %%
cont_selected["Mês"] = pd.to_datetime(cont_selected["Data de Emissão"], dayfirst=True).dt.month
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_17976\141097912.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   cont_selected["Mês"] = pd.to_datetime(cont_selected["Data de Emissão"], dayfirst=True).dt.month
# C:\Users\abarr\AppData\Local\Temp\ipykernel_17976\141097912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_selected["Mês"] = pd.to_datetime(cont_selected["Data de Emissão"], dayfirst=True).dt.month

# %%
cont_selected.head(10)
# Out:
#   Data de Emissão                            Nome do Adquirente  \
# 0      2025-12-27  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA
# 1      2025-12-05                          OLINDA & BEATRIZ LDA
# 2      2025-12-05  EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA
# 3      2025-12-05                             EVORAL CENTER LDA
# 4      2025-11-22  IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA
# 5      2025-11-22                          OLINDA & BEATRIZ LDA
# 6      2025-11-11  EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA
# 7      2025-11-10                             EVORAL CENTER LDA
# 8      2025-10-26                          OLINDA & BEATRIZ LDA
# 9      2025-10-14                          OLINDA & BEATRIZ LDA
#
#   Total do Documento (em euros)  Mês
# 0                        296,43   12
# 1                       199,392   12
# 2                       668,588   12
# 3                         169,4   12
# 4                        78,286   11
# 5                       280,819   11
# 6                       558,788   11
# 7                       148,418   11
# 8                        277,35   10
# 9                         304,3   10

# %%
cont_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Data de Emissão                57 non-null     object
#  1   Nome do Adquirente             57 non-null     object
#  2   Total do Documento (em euros)  57 non-null     object
#  3   Mês                            57 non-null     int32
# dtypes: int32(1), object(3)
# memory usage: 1.7+ KB

# %%
cont_selected["Total do Documento (em euros)"] = cont_selected["Total do Documento (em euros)"].str.replace(".", "")
cont_selected["Total do Documento (em euros)"] = cont_selected["Total do Documento (em euros)"].str.replace(",", ".").astype(float)
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_17976\2682115670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_selected["Total do Documento (em euros)"] = cont_selected["Total do Documento (em euros)"].str.replace(".", "")
# C:\Users\abarr\AppData\Local\Temp\ipykernel_17976\2682115670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_selected["Total do Documento (em euros)"] = cont_selected["Total do Documento (em euros)"].str.replace(",", ".").astype(float)

# %%
total_mes = cont_selected.groupby("Mês")["Total do Documento (em euros)"].sum()
#total_mes["month"] = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
# total_mes = pd.DataFrame(total_mes).set_index("month")

# %%
plt.bar(total_mes.index, total_mes.values)
plt.show()

# %%
total_nome = cont_selected.groupby("Nome do Adquirente")["Total do Documento (em euros)"].sum()
# total_mes["month"] = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
# total_mes = pd.DataFrame(total_mes).set_index("month")

# %%
plt.bar(total_nome.index, total_nome.values)
plt.show()

# %%
nome_por_mes = cont_selected.groupby(["Nome do Adquirente","Mês"])["Total do Documento (em euros)"].sum()
mes_por_nome = cont_selected.groupby(["Mês","Nome do Adquirente"])["Total do Documento (em euros)"].sum()

# %%
mes_por_nome
# Out:
# Mês  Nome do Adquirente
# 1    CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA        176.720
#      EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           763.940
#      EVORAL CENTER LDA                                       43.870
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           765.130
#      UNIDADE LOCAL DE SAÚDE DO ALENTEJO CENTRAL, E.P.E.    1530.000
# 2    CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA        187.060
#      EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA          2289.950
#      EVORAL CENTER LDA                                      193.970
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           464.590
#      OLINDA & BEATRIZ LDA                                  1611.000
# 3    CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA        327.450
#      EVORAL CENTER LDA                                      279.500
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           305.020
#      OLINDA & BEATRIZ LDA                                   492.860
# 4    CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA        114.140
#      EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA          1698.170
#      EVORAL CENTER LDA                                      335.820
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           182.790
#      OLINDA & BEATRIZ LDA                                   750.550
# 5    CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA        118.210
#      EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA          1144.190
#      EVORAL CENTER LDA                                      119.350
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA            27.370
# 6    EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           837.760
#      EVORAL CENTER LDA                                      296.830
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           757.960
#      OLINDA & BEATRIZ LDA                                  1518.420
# 7    EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA          1161.780
#      EVORAL CENTER LDA                                       94.320
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           197.210
#      OLINDA & BEATRIZ LDA                                  1071.540
#      UNIDADE LOCAL DE SAÚDE DO ALENTEJO CENTRAL, E.P.E.     360.000
# 8    EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           451.770
#      EVORAL CENTER LDA                                       53.900
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           101.560
# 9    EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           652.060
#      EVORAL CENTER LDA                                       53.900
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           185.920
#      OLINDA & BEATRIZ LDA                                   664.110
# 10   EVORAL CENTER LDA                                       93.680
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           350.070
#      OLINDA & BEATRIZ LDA                                   581.650
# 11   EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           558.788
#      EVORAL CENTER LDA                                      148.418
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA            78.286
#      OLINDA & BEATRIZ LDA                                   280.819
# 12   EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA           668.588
#      EVORAL CENTER LDA                                      169.400
#      IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA           296.430
#      OLINDA & BEATRIZ LDA                                   199.392
# Name: Total do Documento (em euros), dtype: float64

# %%
nome_por_mes
# Out:
# Nome do Adquirente                                  Mês
# CLINICA MEDICA E DENTARIA DE SANTA MADALENA LDA     1       176.720
#                                                     2       187.060
#                                                     3       327.450
#                                                     4       114.140
#                                                     5       118.210
# EQUIPADENTE LABORATORIO PROTESE DENTARIA LDA        1       763.940
#                                                     2      2289.950
#                                                     4      1698.170
#                                                     5      1144.190
#                                                     6       837.760
#                                                     7      1161.780
#                                                     8       451.770
#                                                     9       652.060
#                                                     11      558.788
#                                                     12      668.588
# EVORAL CENTER LDA                                   1        43.870
#                                                     2       193.970
#                                                     3       279.500
#                                                     4       335.820
#                                                     5       119.350
#                                                     6       296.830
#                                                     7        94.320
#                                                     8        53.900
#                                                     9        53.900
#                                                     10       93.680
#                                                     11      148.418
#                                                     12      169.400
# IDBL - INSTITUTO MEDICO-DENTARIO DE BEJA LDA        1       765.130
#                                                     2       464.590
#                                                     3       305.020
#                                                     4       182.790
#                                                     5        27.370
#                                                     6       757.960
#                                                     7       197.210
#                                                     8       101.560
#                                                     9       185.920
#                                                     10      350.070
#                                                     11       78.286
#                                                     12      296.430
# OLINDA & BEATRIZ LDA                                2      1611.000
#                                                     3       492.860
#                                                     4       750.550
#                                                     6      1518.420
#                                                     7      1071.540
#                                                     9       664.110
#                                                     10      581.650
#                                                     11      280.819
#                                                     12      199.392
# UNIDADE LOCAL DE SAÚDE DO ALENTEJO CENTRAL, E.P.E.  1      1530.000
#                                                     7       360.000
# Name: Total do Documento (em euros), dtype: float64

# %%
plt.bar(nome_por_mes.index, nome_por_mes.values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.bar(nome_por_mes.index, nome_por_mes.values)
#       2 plt.show()
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2979, in bar(x, height, width, bottom, align, data, **kwargs)
#    2968 @_copy_docstring_and_deprecators(Axes.bar)
#    2969 def bar(
#    2970     x: float | ArrayLike,
#    (...)   2977     **kwargs,
#    2978 ) -> BarContainer:
# -> 2979     return gca().bar(
#    2980         x,
#    2981         height,
#    2982         width=width,
#    2983         bottom=bottom,
#    2984         align=align,
#    2985         **({"data": data} if data is not None else {}),
#    2986         **kwargs,
#    2987     )
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:2555, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2549         x = 0
#    2551 if orientation == 'vertical':
#    2552     # It is possible for y (bottom) to contain unit information.
#    2553     # However, it is also possible for y=0 for the default and height
#    2554     # to contain unit information.  This will prioritize the units of y.
# -> 2555     self._process_unit_info(
#    2556         [("x", x), ("y", y), ("y", height)], kwargs, convert=False)
#    2557     if log:
#    2558         self.set_yscale('log', nonpositive='clip')
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:2647, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2645     # Update from data if axis is already set but no unit is set yet.
#    2646     if axis is not None and data is not None and not axis.have_units():
# -> 2647         axis.update_units(data)
#    2648 for axis_name, axis in axis_map.items():
#    2649     # Return if no axis is set.
#    2650     if axis is None:
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File c:\Users\abarr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple
